# %% [markdown]
# # Smart Phone Addiction Data Cleaning

# %% [markdown]
# ## Introduction
# The rapid growth of smartphone usage has significantly transformed modern lifestyles, influencing how individuals communicate, work, and spend their leisure time. While smartphones offer convenience and connectivity, excessive usage has raised concerns regarding digital addiction and its impact on mental well-being, productivity, and daily habits.
#
# This project utilizes a dataset comprising information from approximately 7,500 individuals, capturing detailed smartphone usage patterns and behavioral indicators. The dataset includes key variables such as daily screen time, number of app opens, time spent on social media, sleep duration, productivity levels, and frequency of phone checking. Additionally, demographic attributes like age, gender, and occupation enable a deeper understanding of how different user groups interact with smartphones.
#
# The primary objective of this analysis is to explore patterns, trends, and relationships within the data to better understand smartphone usage behavior and its potential consequences.
#
# Through this analysis, the purpose is to identify the indicators of smartphone addiction, examine their impact on lifestyle factors such as sleep and productivity, and provide data-driven insights that can contribute to discussions around digital well-being.

# %% [markdown]
# ### Questions and Hypotheses
# 1. **Does increased daily screen time affects an individual's productivity and effeciency?**
#     - **Hypotheses**: Higher daily screen time is associated with lower productivity levels.
#
#
# 2. **Does spending more time on social media impact sleep duration?**
#     - **Hypotheses**: Individuals who spend more time on social media tend to have shorter sleep durations.
#
#
# 3. **Do people spend more time on smartphones during weekends compared to weekdays?**
#     - **Hypotheses**: Average screen time is higher on weekends than on weekdays
#
#
# 4. **Is there any relationship between daily screen time and stress_levels?**
#     - **Hypotheses**: Often high duration of daily screen time is associated with high stress levels, but it is also possible that if properly used for entertainment it might decrease the stress
#
#
# 5. **Do individuals who spend more time gaming have different sleep durations?**
#     - **Hypotheses**: Higher gaming hours are always associated with reduced sleep duration

# %% [markdown]
# ## Step 1 - Load Data

# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset/smartphone_addiction_analysis.csv')
df.head()
# Out:
#   transaction_id user_id  age gender  daily_screen_time_hours  \
# 0       TXN00001  U00001   21   Male                     3.23
# 1       TXN00002  U00002   24  Other                     5.09
# 2       TXN00003  U00003   31  Other                     6.06
# 3       TXN00004  U00004   32  Other                     7.83
# 4       TXN00005  U00005   25   Male                     9.96
#
#    social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                2.01          0.89              4.55         7.55
# 1                3.81          2.24              4.44         7.66
# 2                1.36          3.83              2.35         4.92
# 3                5.85          1.51              3.54         8.23
# 4                5.92          3.42              5.27         6.21
#
#    notifications_per_day  app_opens_per_day  weekend_screen_time stress_level  \
# 0                    248                154                 3.95       Medium
# ...

# %%
df.shape
# Out:
# (7500, 16)

# %%
# Checking if any columns have null values
df.isnull().sum()
# Out:
# transaction_id               0
# user_id                      0
# age                          0
# gender                       0
# daily_screen_time_hours      0
# social_media_hours           0
# gaming_hours                 0
# work_study_hours             0
# sleep_hours                  0
# notifications_per_day        0
# app_opens_per_day            0
# weekend_screen_time          0
# stress_level                 0
# academic_work_impact         0
# addiction_level            819
# addicted_label               0
# dtype: int64

# %%
# Summary statistics
df.describe()
# Out:
#                age  daily_screen_time_hours  social_media_hours  gaming_hours  \
# count  7500.000000              7500.000000         7500.000000   7500.000000
# mean     26.568800                 7.499912            3.273484      2.014183
# std       5.197108                 2.609188            1.585342      1.146039
# min      18.000000                 3.000000            0.500000      0.000000
# 25%      22.000000                 5.220000            1.910000      1.020000
# 50%      27.000000                 7.525000            3.270000      2.040000
# 75%      31.000000                 9.810000            4.630000      2.990000
# max      35.000000                12.000000            6.000000      4.000000
#
#        work_study_hours  sleep_hours  notifications_per_day  \
# count       7500.000000  7500.000000            7500.000000
# mean           3.242420     6.737561             134.257333
# std            1.600765     1.283605              66.586883
# ...

# %%
# Checking dataset structure
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           7500 non-null   str
#  1   user_id                  7500 non-null   str
#  2   age                      7500 non-null   int64
#  3   gender                   7500 non-null   str
#  4   daily_screen_time_hours  7500 non-null   float64
#  5   social_media_hours       7500 non-null   float64
#  6   gaming_hours             7500 non-null   float64
#  7   work_study_hours         7500 non-null   float64
#  8   sleep_hours              7500 non-null   float64
#  9   notifications_per_day    7500 non-null   int64
#  10  app_opens_per_day        7500 non-null   int64
#  11  weekend_screen_time      7500 non-null   float64
#  12  stress_level             7500 non-null   str
#  13  academic_work_impact     7500 non-null   str
# ...

# %% [markdown]
# ## Step 2 - Data Cleaning

# %%
# Checking Duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Converting data types
df['stress_level'] = df['stress_level'].astype('category')

# %%
df.head()
# Out:
#   transaction_id user_id  age gender  daily_screen_time_hours  \
# 0       TXN00001  U00001   21   Male                     3.23
# 1       TXN00002  U00002   24  Other                     5.09
# 2       TXN00003  U00003   31  Other                     6.06
# 3       TXN00004  U00004   32  Other                     7.83
# 4       TXN00005  U00005   25   Male                     9.96
#
#    social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                2.01          0.89              4.55         7.55
# 1                3.81          2.24              4.44         7.66
# 2                1.36          3.83              2.35         4.92
# 3                5.85          1.51              3.54         8.23
# 4                5.92          3.42              5.27         6.21
#
#    notifications_per_day  app_opens_per_day  weekend_screen_time stress_level  \
# 0                    248                154                 3.95       Medium
# ...

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      2553
# Other     2486
# Female    2461
# Name: count, dtype: int64

# %%
df['stress_level'].value_counts()
# Out:
# stress_level
# High      2560
# Low       2503
# Medium    2437
# Name: count, dtype: int64

# %%
df['academic_work_impact'].value_counts()
# Out:
# academic_work_impact
# No     3753
# Yes    3747
# Name: count, dtype: int64

# %%
df['addiction_level'].value_counts()
# Out:
# addiction_level
# Moderate    2874
# Severe      2434
# Mild        1373
# Name: count, dtype: int64

# %%
df['addiction_level'].unique()
# Out:
# <StringArray>
# [nan, 'Mild', 'Moderate', 'Severe']
# Length: 4, dtype: str

# %%
df['addiction_level'] = df['addiction_level'].fillna('None')

# %%
df['addiction_level'].value_counts()
# Out:
# addiction_level
# Moderate    2874
# Severe      2434
# Mild        1373
# None         819
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   transaction_id user_id  age gender  daily_screen_time_hours  \
# 0       TXN00001  U00001   21   Male                     3.23
# 1       TXN00002  U00002   24  Other                     5.09
# 2       TXN00003  U00003   31  Other                     6.06
# 3       TXN00004  U00004   32  Other                     7.83
# 4       TXN00005  U00005   25   Male                     9.96
#
#    social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                2.01          0.89              4.55         7.55
# 1                3.81          2.24              4.44         7.66
# 2                1.36          3.83              2.35         4.92
# 3                5.85          1.51              3.54         8.23
# 4                5.92          3.42              5.27         6.21
#
#    notifications_per_day  app_opens_per_day  weekend_screen_time stress_level  \
# 0                    248                154                 3.95       Medium
# ...

# %%
# New features

# Total usage for social media and gaming
df['total_usage'] = df['social_media_hours'] + df['gaming_hours']

# Difference in screen usage during weekend and weekdays
df['week_usage_dff'] = df['weekend_screen_time'] - df['daily_screen_time_hours']

df.head()
# Out:
#   transaction_id user_id  age gender  daily_screen_time_hours  \
# 0       TXN00001  U00001   21   Male                     3.23
# 1       TXN00002  U00002   24  Other                     5.09
# 2       TXN00003  U00003   31  Other                     6.06
# 3       TXN00004  U00004   32  Other                     7.83
# 4       TXN00005  U00005   25   Male                     9.96
#
#    social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                2.01          0.89              4.55         7.55
# 1                3.81          2.24              4.44         7.66
# 2                1.36          3.83              2.35         4.92
# 3                5.85          1.51              3.54         8.23
# 4                5.92          3.42              5.27         6.21
#
#    notifications_per_day  app_opens_per_day  weekend_screen_time stress_level  \
# 0                    248                154                 3.95       Medium
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           7500 non-null   str
#  1   user_id                  7500 non-null   str
#  2   age                      7500 non-null   int64
#  3   gender                   7500 non-null   str
#  4   daily_screen_time_hours  7500 non-null   float64
#  5   social_media_hours       7500 non-null   float64
#  6   gaming_hours             7500 non-null   float64
#  7   work_study_hours         7500 non-null   float64
#  8   sleep_hours              7500 non-null   float64
#  9   notifications_per_day    7500 non-null   int64
#  10  app_opens_per_day        7500 non-null   int64
#  11  weekend_screen_time      7500 non-null   float64
#  12  stress_level             7500 non-null   category
#  13  academic_work_impact     7500 non-null   str
# ...

# %%
# Encoding categorical values:
df['addiction_level_encoded'] = df['addiction_level'].map({
    'None': 0,
    'Mild': 1,
    'Moderate': 2,
    'Severe': 3
})

# %%
df.head()
# Out:
#   transaction_id user_id  age gender  daily_screen_time_hours  \
# 0       TXN00001  U00001   21   Male                     3.23
# 1       TXN00002  U00002   24  Other                     5.09
# 2       TXN00003  U00003   31  Other                     6.06
# 3       TXN00004  U00004   32  Other                     7.83
# 4       TXN00005  U00005   25   Male                     9.96
#
#    social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                2.01          0.89              4.55         7.55
# 1                3.81          2.24              4.44         7.66
# 2                1.36          3.83              2.35         4.92
# 3                5.85          1.51              3.54         8.23
# 4                5.92          3.42              5.27         6.21
#
#    notifications_per_day  app_opens_per_day  weekend_screen_time stress_level  \
# 0                    248                154                 3.95       Medium
# ...

# %%
# Checking if daily screen time is > 24 hours
(df['daily_screen_time_hours'] > 24).value_counts()
# Out:
# daily_screen_time_hours
# False    7500
# Name: count, dtype: int64

# %%
# Checking if sleep hours > 24
(df['sleep_hours'] > 24).value_counts()
# Out:
# sleep_hours
# False    7500
# Name: count, dtype: int64

# %%
# Checking if sleep hours < 0
(df['sleep_hours'] <= 0).value_counts()
# Out:
# sleep_hours
# False    7500
# Name: count, dtype: int64

# %%
# Checking unique values in transaction id and user id
df['transaction_id'].unique()
# Out:
# <StringArray>
# ['TXN00001', 'TXN00002', 'TXN00003', 'TXN00004', 'TXN00005', 'TXN00006',
#  'TXN00007', 'TXN00008', 'TXN00009', 'TXN00010',
#  ...
#  'TXN07491', 'TXN07492', 'TXN07493', 'TXN07494', 'TXN07495', 'TXN07496',
#  'TXN07497', 'TXN07498', 'TXN07499', 'TXN07500']
# Length: 7500, dtype: str

# %%
df['user_id'].unique()
# Out:
# <StringArray>
# ['U00001', 'U00002', 'U00003', 'U00004', 'U00005', 'U00006', 'U00007',
#  'U00008', 'U00009', 'U00010',
#  ...
#  'U07491', 'U07492', 'U07493', 'U07494', 'U07495', 'U07496', 'U07497',
#  'U07498', 'U07499', 'U07500']
# Length: 7500, dtype: str

# %%
# Deleting transaction_id as User_id serves unique values
df.drop('transaction_id', axis='columns', inplace = True)

# %%
df.head()
# Out:
#   user_id  age gender  daily_screen_time_hours  social_media_hours  \
# 0  U00001   21   Male                     3.23                2.01
# 1  U00002   24  Other                     5.09                3.81
# 2  U00003   31  Other                     6.06                1.36
# 3  U00004   32  Other                     7.83                5.85
# 4  U00005   25   Male                     9.96                5.92
#
#    gaming_hours  work_study_hours  sleep_hours  notifications_per_day  \
# 0          0.89              4.55         7.55                    248
# 1          2.24              4.44         7.66                    127
# 2          3.83              2.35         4.92                     44
# 3          1.51              3.54         8.23                    178
# 4          3.42              5.27         6.21                    136
#
#    app_opens_per_day  weekend_screen_time stress_level academic_work_impact  \
# ...

# %%
df.to_csv('Dataset/cleaned_data.csv', index=False)
